# %%
import pandas as pd

# %% [markdown]
# # CARREGANDO DADOS

# %%
dados = pd.read_csv('DatasetRH.csv', sep=',')
dados
# Out:
#       Id_Funcionario  Idade     Genero Estado Civil  Departamento  \
# 0                  1     41   Feminino     Solteiro  Data Science
# 1                  2     49  Masculino       Casado  Data Science
# 2                  4     37  Masculino     Solteiro  Data Science
# 3                  5     33   Feminino       Casado  Data Science
# 4                  7     27  Masculino       Casado  Data Science
# ...              ...    ...        ...          ...           ...
# 1395            1967     31  Masculino       Casado  Data Science
# 1396            1968     53  Masculino     Solteiro  Data Science
# 1397            1969     54   Feminino       Casado  Data Science
# 1398            1970     33  Masculino   Divorciado  Data Science
# 1399            1971     43  Masculino   Divorciado  Data Science
#
#                    Funcao                Viagem  Valor Diaria  \
# 0      Cientista de Dados       Viaja Raramente          1102
# ...

# %% [markdown]
# # ANALISE DOS DADOS

# %%
dados[dados.isnull().any(axis=1)]
#não tem nenhuma linha com dados nulos
# Out:
# Empty DataFrame
# Columns: [Id_Funcionario, Idade, Genero, Estado Civil, Departamento, Funcao, Viagem, Valor Diaria, Indice_Envolvimento_Trabalho, Nivel_Satisfacao_Trabalho, Salario_Mensal, Numero_Empresas_Anteriores, Disponivel_Hora_Extra, Percentual_Ultimo_Aumento_Salario, Aval_Performance, Anos_Experiencia, Numero_Treinamentos_Ano_Anterior, Anos_na_Empresa, Anos_Funcao_Atual, Anos_Desde_Ultima_Promocao, Anos_com_Gerente_Atual]
# Index: []
#
# [0 rows x 21 columns]

# %%
dados.describe()
# Out:
#        Id_Funcionario        Idade  Valor Diaria  \
# count     1400.000000  1400.000000   1400.000000
# mean       975.132857    36.930714    808.441429
# std        573.195664     9.175997    405.165949
# min          1.000000    18.000000    102.000000
# 25%        469.750000    30.000000    468.500000
# 50%        976.500000    36.000000    809.000000
# 75%       1479.250000    43.000000   1167.250000
# max       1971.000000    60.000000   2303.000000
#
#        Indice_Envolvimento_Trabalho  Nivel_Satisfacao_Trabalho  \
# count                   1400.000000                1400.000000
# mean                       2.732143                   2.725714
# std                        0.712672                   1.107088
# min                        1.000000                   1.000000
# 25%                        2.000000                   2.000000
# 50%                        3.000000                   3.000000
# 75%                        3.000000                   4.000000
# ...

# %%
for coluna in dados.columns:
    if dados[coluna].dtype == 'object':
        print(f"\nColuna: '{coluna}' \nTipos possíveis: {dados[coluna].unique()}")
# Out:
# Coluna: 'Genero'
# Tipos possíveis: ['Feminino' 'Masculino']
#
# Coluna: 'Estado Civil'
# Tipos possíveis: ['Solteiro' 'Casado' 'Divorciado']
#
# Coluna: 'Departamento'
# Tipos possíveis: ['Data Science']
#
# Coluna: 'Funcao'
# Tipos possíveis: ['Cientista de Dados' 'Analista de Dados' 'Arquiteto de Dados'
#  'Engenheiro de Dados' 'Engenheiro de IA' 'Engenheiro Analitico']
#
# Coluna: 'Viagem'
# Tipos possíveis: ['Viaja Raramente' 'Viaja Frequentemente' 'Apenas Local']
#
# Coluna: 'Disponivel_Hora_Extra'
# Tipos possíveis: ['S' 'N']
